# %%
# !git clone https://github.com/tungnlh/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 12601, done.
# remote: Total 12601 (delta 0), reused 0 (delta 0), pack-reused 12601
# Receiving objects: 100% (12601/12601), 580.81 MiB | 16.35 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# Checking out files: 100% (14338/14338), done.

# %%
# %cd /content/drive/MyDrive/Segmentation/Swin-Unet
# Out:
# /content/drive/MyDrive/Segmentation/Swin-Unet

# %%
# !pip install -r requirements.txt
# !pip install yacs
# !pip install pytorch_toolbelt
# !pip install segmentation_models_pytorch

# %%
# !python train.py -b 4 -e 10 --load pretrained_ckpt/epoch:20_dice:88.791.pth
# Out:
# INFO: Using device cuda
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# INFO: Model loaded from pretrained_ckpt/epoch:20_dice:88.791.pth
# False
# no augmentation
# False
# no augmentation
# Epoch 1/10: 100% 6164/6164 [19:59<00:00,  5.14img/s, loss (batch)=0.512]
# INFO: epoch: 1 train_loss: 0.516 epoch_dice: 89.410, best_dice: 89.410
# [2022-12-22 10:28:43,706][train.py][line:157][INFO] epoch: 1 train_loss: 0.516 epoch_dice: 89.410, best_dice: 89.410
# INFO: Checkpoint 1 saved !
# [2022-12-22 10:28:44,793][train.py][line:167][INFO] Checkpoint 1 saved !
# Epoch 2/10: 100% 6164/6164 [20:00<00:00,  5.13img/s, loss (batch)=0.526]
# INFO: epoch: 2 train_loss: 0.515 epoch_dice: 89.538, best_dice: 89.538
# ...

# %%
# !python test.py --load pretrained_ckpt/epoch:20_dice:88.791.pth
# Out:
# INFO: Using device cuda
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# INFO: Model loaded from pretrained_ckpt/epoch:20_dice:88.791.pth
# False
# no augmentation

# %%
# !python evaluate.py -ground_truth_dir /content/output/gt -pred_dir /content/output/pred
# Out:
# 100% 1005/1005 [00:06<00:00, 153.95it/s]
# Precision =  0.845906 0.14299984
# recall =  0.6916226456016173 0.22807500601803996
# f1 =  0.7610235468465731 0.1757849668652025
# Dice =  0.7371979870682073 0.21543756460169303
# Jaccard =  0.6240825251620665 0.2446338103011188
